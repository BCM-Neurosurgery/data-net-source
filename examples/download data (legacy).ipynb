# %%
import parsers
from common.utils.rune import get_client,get_watch_data,get_bilateral_watch_data
from common.utils.rclone import copy, list_remote
import subprocess
import os
import subprocess
import matlab.engine
import re
import shutil
from common.utils.time import unix_to_timestamps, timestamp_to_unix
from common.utils.ingest import storage_format_date
import numpy as np
import pandas as pd
from scipy import signal
import datetime
import matplotlib.pyplot as plt
import shutil

# %%
ucsf_all_files = subprocess.check_output(["ssh", "rbechto2@10.37.129.11","ls","/media/dropbox_hdd/Starr\ Lab\ Dropbox/RC+S\ Patient\ Un-Synced\ Data/RCS07\ Un-Synced\ Data/SummitData/SummitContinuousBilateralStreaming/RCS07R"]).decode("utf-8")
ucsf_session_names = [i for i in ucsf_all_files.split() if 'Session' in i]
data_frame = pd.Series(ucsf_session_names).to_frame()
data_frame.to_csv('./saved_session_logs/processed_sessions_R.csv')

# %%
myRCSParser = parsers.RCSParser()
myRCSParser.full_parse()
# Out:
# START
# Aggregate
# Anonymize
#
# failures =
#
#   0x0 empty cell array
#
# To csv
# Collecting Device Settings data
# Collecting Stimulation Settings from Device Settings file
# Collecting Stimulation Settings from Stim Log file
# File loaded in 0.00 seconds
# Collecting Adaptive Settings from Device Settings file
# Collecting Event Information from Event Log file
# File loaded in 0.00 seconds
# Checking for Time Domain Data
# File loaded in 2.57 seconds
# Loading Time Domain Data
# finished unpacking into matrix in 2.85 seconds
# Creating derivedTimes for time domain:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 4767
# Number of chunks with time calculated from PacketGenTime: 4767
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Currently on chunk 1000 of 4767
# Currently on chunk 2000 of 4767
# Currently on chunk 3000 of 4767
# Currently on chunk 4000 of 4767
# Cleaning up output table
# Checking for Accelerometer Data
# File loaded in 0.57 seconds
# Loading Accelerometer Data
# finished unpacking into matrix in 1.14 seconds
# Creating derivedTimes for accelerometer:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 2577
# Number of chunks with time calculated from PacketGenTime: 2577
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Currently on chunk 1000 of 2577
# Currently on chunk 2000 of 2577
# Cleaning up output table
# Checking for Power Data
# Loading Power Data
# Power data  is empty
# Creating dummy event table
# Checking for FFT Data
# File loaded in 0.00 seconds
# Checking for Adaptive Data
# File loaded in 4.92 seconds
# Loading Adaptive Data
# Creating derivedTimes for Adaptive:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 4351
# Number of chunks with time calculated from PacketGenTime: 4351
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Currently on chunk 1000 of 4351
# Currently on chunk 2000 of 4351
# Currently on chunk 3000 of 4351
# Currently on chunk 4000 of 4351
# Cleaning up output table
# Harmonizing time of Accelerometer data with unifiedDerivedTimes
# Warning: Same time assigned to 3 set(s) of samples during time harmonization
# > In harmonizeTimeAcrossDataStreams (line 50)
# In ProcessRCS (line 336)
# In convert_json_batch_callable>save_session_as_csv (line 68)
# In convert_json_batch_callable (line 43)
# Harmonizing time of Adaptive data with unifiedDerivedTimes
# Collecting Device Settings data
# Collecting Stimulation Settings from Device Settings file
# Collecting Stimulation Settings from Stim Log file
# File loaded in 0.00 seconds
# Collecting Adaptive Settings from Device Settings file
# Collecting Event Information from Event Log file
# File loaded in 0.00 seconds
# Checking for Time Domain Data
# File loaded in 1.06 seconds
# Loading Time Domain Data
# finished unpacking into matrix in 1.59 seconds
# Creating derivedTimes for time domain:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 453
# Number of chunks with time calculated from PacketGenTime: 453
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Cleaning up output table
# Checking for Accelerometer Data
# File loaded in 0.30 seconds
# Loading Accelerometer Data
# finished unpacking into matrix in 0.58 seconds
# Creating derivedTimes for accelerometer:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 425
# Number of chunks with time calculated from PacketGenTime: 425
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Cleaning up output table
# Checking for Power Data
# Loading Power Data
# Power data  is empty
# Creating dummy event table
# Checking for FFT Data
# File loaded in 0.00 seconds
# Checking for Adaptive Data
# File loaded in 2.25 seconds
# Loading Adaptive Data
# Creating derivedTimes for Adaptive:
# Identifying and removing bad packets
# Chunking data
# Determining start time of each chunk
# Number of chunks: 478
# Number of chunks with time calculated from PacketGenTime: 478
# Shifting chunks to align with sampling rate
# Creating derivedTime for each sample
# Cleaning up output table
# Harmonizing time of Accelerometer data with unifiedDerivedTimes
# Warning: Same time assigned to 6 set(s) of samples during time harmonization
# > In harmonizeTimeAcrossDataStreams (line 50)
# In ProcessRCS (line 336)
# In convert_json_batch_callable>save_session_as_csv (line 68)
# In convert_json_batch_callable (line 43)
# Harmonizing time of Adaptive data with unifiedDerivedTimes
#
# failures =
#
#   1x2 cell array
#
#     {'./temp/combined_anonymized_j...'}    {'./temp/combined_anonymized_j...'}

# %%
for i in ['L','R']:
    current_session_on_wasabi = pd.read_csv('./saved_session_logs/processed_sessions_' + i + '.csv').to_numpy()[:,1]
    
    
    ucsf_all_files = subprocess.check_output(["ssh", "rbechto2@10.37.129.11","ls","/media/dropbox_hdd/Starr\ Lab\ Dropbox/RC+S\ Patient\ Un-Synced\ Data/RCS07\ Un-Synced\ Data/SummitData/SummitContinuousBilateralStreaming/RCS07"+i]).decode("utf-8")
    ucsf_session_names = [i for i in ucsf_all_files.split() if 'Session' in i]
    
    new_session_folders = np.array(list(set(ucsf_session_names) -set(current_session_on_wasabi)))
    

    
    
    
    
    
    
#     one_week_ago_timestamp = (datetime.datetime.today() - datetime.timedelta(days=14))
#     one_week_ago_date = int(one_week_ago_timestamp.strftime('%Y%m%d'))
#     recent_dates_mask = [i >= one_week_ago_date for i in current_dates]
#     recent_dates = current_dates[recent_dates_mask]

# %%
unix_week_ago = timestamp_to_unix([pd.Timestamp(one_week_ago_timestamp)])[0]*1000
session_unix_times = np.asarray([int(i[7:]) for i in ucsf_session_names])
recent_ucsf_sessions_mask = session_unix_times > unix_week_ago
recent_ucsf_sessions = session_unix_times[recent_ucsf_sessions_mask]
recent_ucsf_sessions

for timestamp in recent_ucsf_sessions:
    print(timestamp)
    if np.any([start_range <= timestamp <= end_range for start_range,end_range in wasabi_current_session_time_ranges]):
        print('in wasabi')
    else:
        print('not in wasabi')
        #continue

# %%
def get_new_session_names(side):
    current_session_on_wasabi = pd.read_csv('./saved_session_logs/processed_sessions_' + side + '.csv').to_numpy()[:,1]
    
    
    ucsf_all_files = subprocess.check_output(["ssh", "rbechto2@10.37.129.11","ls","/media/dropbox_hdd/Starr\ Lab\ Dropbox/RC+S\ Patient\ Un-Synced\ Data/RCS07\ Un-Synced\ Data/SummitData/SummitContinuousBilateralStreaming/RCS07"+side]).decode("utf-8")
    ucsf_session_names = [i for i in ucsf_all_files.split() if 'Session' in i]
    
    new_session_folders = list(set(ucsf_session_names) -set(current_session_on_wasabi))
    
    updated_ucsf_session_names = ucsf_session_names + new_session_folders
    
    #removed _update from file name once done building the code
    pd.Series(updated_ucsf_session_names).to_frame().to_csv('./saved_session_logs/processed_sessions_'+side+'_updated.csv')
    
    return np.array(new_session_folders)


def download_session_data(side, session_folder_names):
        session_paths = ["rbechto2@10.37.129.11:'/media/dropbox_hdd/Starr Lab Dropbox/RC+S Patient Un-Synced Data/RCS07 Un-Synced Data/SummitData/SummitContinuousBilateralStreaming/RCS07" + side + f"/{i}'" for i in session_folder_names]
        p = subprocess.Popen(["scp", "-r" ,*session_paths, "./temp/combined_original/"])
        # TODO: change to p.communicate and get the output and error message
        p.wait(1800)

def upload_to_wasabi():
    #copy('./temp/combined_anonymized_json_csv/.', 'secret_sauce:/rcs07/rcs_v2/')
    return None

def clean_directory():
        shutil.rmtree('./temp/')
        os.mkdir('./temp/combined_original')
        return None

# %%
for i in ['L','R']:
    get_new_session_names(i)

# %%
[*1657213633000,**1657214350000]      [*1657250520000,**1657262760000]



                                     [1657257920435, 1657259535039]
                                     [1657225992299, 1657233867801]
                                     [*1657257921190, **1657259534804]
                                     [1657225993240, 1657233867746]
[*1657213735857, **1657214339739]    [*1657213735857, **1657214339739]

# %%
time_range1 = [1657177200,1658855600] # all of july 7th
time_range2 = [1657213633,1657214350] # first block
time_range3 = [1657250520,1657262760] # second block
my_range = [time_range1,time_range2,time_range3]
myclient = get_client()

for i in range(3):


    # wrist_params = {
    # 'patient_id': 'rcs07',
    # 'left_watch_id': '8QuY9OFb',
    # 'right_watch_id': 'RElEtNme',
    # 'time_range': time_range
    # }

    # rcs_params = {
    # 'patient_id': 'rcs07',
    # 'left_watch_id': 'NPC700419H',
    # 'right_watch_id': 'NPC700403H',
    # 'time_range': time_range
    # }

    left_watch_params = {
        'patient_id': 'rcs07',
        'device_id': '8QuY9OFb',
        'start_time': my_range[i][0],
        'end_time': my_range[i][1]
    }

    a=get_watch_data(myclient, left_watch_params , 'accel')
    plt.figure()
    plt.plot(a['z'])

# %%
path = '/Users/raphaelb/Documents/UW/Research/gridlab/optimal/data/rcs07/rcs/combined_anonymized_json_csv/20220707/'
folder_names = ['rcs_left_1657213735857_1657214339739', 'rcs_left_1657225993240_1657233867746', 'rcs_left_1657257921190_1657259534804', 'rcs_right_1657225992299_1657233867801', 'rcs_right_1657257920435_1657259535039']

for i in folder_names:
    mya = pd.read_csv(path + i + '/AccelTimeDomain.csv')
    plt.figure()
    plt.plot(mya['accel_z'])

# %%
fft_size = 300
plt.figure()
plt.title('PSD of Right Apple Watch Acceleration')
a = np.linalg.norm(open_accel[1],axis=1)
f, Pxx_den = signal.periodogram(a, 50,nfft=fft_size)
plt.semilogy(f, Pxx_den)
plt.ylim([1e-9, 1e2])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()

# plt.figure()
# plt.title('PSD of Right Apple Watch Acceleration (Adaptive Stim 2.4mA)')
a = np.linalg.norm(high_accel[1],axis=1)
f, Pxx_den = signal.periodogram(a, 50,nfft=fft_size)
plt.semilogy(f, Pxx_den)
# plt.ylim([1e-9, 1e2])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()

# plt.figure()
# plt.title('PSD of Right Apple Watch Acceleration (Adaptive Stim 1.6mA)')
a = np.linalg.norm(low_accel[1],axis=1)
f, Pxx_den = signal.periodogram(a, 50,nfft=fft_size)
plt.semilogy(f, Pxx_den)
# plt.ylim([1e-9, 1e2])
# plt.xlabel('frequency [Hz]')
# plt.ylabel('PSD [V**2/Hz]')
# plt.show()
plt.legend(['Open','High','Low'])

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
data = np.squeeze(np.asarray([open_severity[0]['unknown'].iloc[1:],high_severity[0]['unknown'].iloc[1:],low_severity[0]['unknown'].iloc[1:]]))
ax.boxplot(data.T)
plt.title('Tremor Probability under 3 Different Stim Conditions')
plt.ylabel('Probability')
plt.ylim([0,1])
ax.set_xticklabels(['Open Stim (2mA)','Adaptaive Stim (2.4mA)','Adaptive Stim (1.6mA)'])

# %%
np.asarray([open_severity[0]["slight"].iloc[1:],low_severity[0]["slight"].iloc[1:],high_severity[0]["slight"].iloc[1:]])

# %%
open_severity[0]

# %%
def get_timestamps(path_to_folder):
    neural_time_domain = pd.read_csv(path_to_folder + '/NeuralTimeDomain.csv')
    start = str(neural_time_domain["timestamp"].iloc[0])
    end = str(neural_time_domain["timestamp"].iloc[-1])
    time_range = [start[0:-4], end[0:-4]]
    return time_range

def get_side(folder_name):
    if 'left' in folder_name:
        return True
    if 'right' in folder_name:
        return False
    
def get_params(side,dual_sided_params):
    if side:
        return {
        'patient_id': dual_sided_params['patient_id'],
        'device_id': dual_sided_params['left_watch_id'],
        'start_time': dual_sided_params['time_range'][0],
        'end_time': dual_sided_params['time_range'][1]}
    else:
        return {
        'patient_id': dual_sided_params['patient_id'],
        'device_id': dual_sided_params['right_watch_id'],
        'start_time': dual_sided_params['time_range'][0],
        'end_time': dual_sided_params['time_range'][1]}
    
    
def timestamps_to_rune_data(timestamps,folder_name):


    wrist_params = {
    'patient_id': 'rcs07',
    'left_watch_id': '8QuY9OFb',
    'right_watch_id': 'RElEtNme',
    'time_range': timestamps
    }
    rcs_params = {
    'patient_id': 'rcs07',
    'left_watch_id': 'NPC700419H',
    'right_watch_id': 'NPC700403H',
    'time_range': timestamps
    }
        
    
    my_accel = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'accel').set_index('timestamp')
    my_rotation = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'rotation').set_index('timestamp')
    my_heart_rate = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'heart rate').set_index('timestamp')
    my_tremor = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'tremor').set_index('timestamp')
    my_tremor_severity = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'tremor severity').set_index('timestamp')
    my_dyskinesia = get_watch_data(myclient, get_params(get_side(folder_name),wrist_params), 'dyskinesia').set_index('timestamp')
    my_lfp = get_watch_data(myclient, get_params(get_side(folder_name),rcs_params), 'lfp').set_index('timestamp')
    my_band_power = get_watch_data(myclient, get_params(get_side(folder_name),rcs_params), 'band power').set_index('timestamp')
    
    return my_accel, my_rotation, my_heart_rate, my_tremor, my_tremor_severity, my_dyskinesia, my_lfp, my_band_power

def output_to_csv(path, date, folder, my_accel, my_rotation, my_heart_rate, my_tremor, my_tremor_severity, my_dyskinesia, my_lfp, my_band_power):

    if get_side(folder):
        full_path =  path + 'rune/' + date + '/rune_left_' + folder[-27:]
    else:
        full_path =  path + 'rune/' + date + '/rune_right_' + folder[-27:]
        
    # If folder doesn't exist, then create it.
    if not os.path.isdir(full_path):
        os.makedirs(full_path)

    
    my_accel.to_csv(full_path + '/accel.csv')
    my_rotation.to_csv(full_path + '/rotation.csv')
    my_heart_rate.to_csv(full_path + '/heart_rate.csv')
    my_tremor.to_csv(full_path + '/tremor.csv')
    my_tremor_severity.to_csv(full_path + '/tremor_severity.csv')
    my_dyskinesia.to_csv(full_path + '/dyskinesia.csv')
    my_lfp.to_csv(full_path + '/lfp.csv')
    my_band_power.to_csv(full_path + '/band_power.csv')

# %%
folder_path = '/Users/raphaelb/Documents/UW/Research/gridlab/optimal/data/rcs07/'
date_dir = os.listdir(folder_path + 'rcs/combined_anonymized_json_csv/')

if '.DS_Store' in date_dir:
    date_dir.remove('.DS_Store')

for i in date_dir:
    session_dir = os.listdir(folder_path + 'rcs/combined_anonymized_json_csv/'+i)
    if '.DS_Store' in session_dir:
        session_dir.remove('.DS_Store')
    for j in session_dir:
        my_timestamps = get_timestamps(folder_path + 'rcs/combined_anonymized_json_csv/'+i+'/'+j)    
        output_to_csv(folder_path,i,j,*timestamps_to_rune_data(my_timestamps,j))
# Out:
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for accel in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for heart rate in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor severity in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for dyskinesia in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for lfp in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for band power in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for accel in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for heart rate in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor severity in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for dyskinesia in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for lfp in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for band power in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for accel in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for heart rate in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor severity in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for dyskinesia in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for lfp in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for band power in time range: 165721373 - 165721433
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for accel in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for heart rate in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor severity in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for dyskinesia in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for lfp in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for band power in time range: 165725792 - 165725953
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for accel in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for heart rate in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for tremor severity in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for dyskinesia in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for lfp in time range: 165722599 - 165723386
#   warnings.warn(warning_message)
# /Users/raphaelb/Documents/UW/Research/gridlab/optimal/data-net-common/common/utils/rune.py:120: UserWarning: No Data for band power in time range: 165722599 - 165723386
#   warnings.warn(warning_message)

# %% [markdown]
# ## Dropbox Code

# %%
#### DROPBOX_ACCESS_TOKEN = 'sl.BJ_794kQETs-AQ7jWJnc--vK2fCQ6RoPolVzvQ4vZEKdYfmYsr5WinUt3b-BCHlEEKjPuV59oGGaUA2ZPXI3JSyNy2F4MTe5bCVegs8z5WbXes0YZT7BF7H4tzX7K_HJPOrXo_Pc'
def dropbox_connect():
    """Create a connection to Dropbox."""

    try:
        dbx = dropbox.Dropbox(DROPBOX_ACCESS_TOKEN)
    except AuthError as e:
        print('Error connecting to Dropbox with access token: ' + str(e))
    return dbx

def dropbox_list_files():
    """Return a Pandas dataframe of files in a given Dropbox folder path in the Apps directory.
    """

    dbx = dropbox_connect()

    try:
        files = dbx.sharing_list_folders().entries
        files_list = []
        for file in files:
            if isinstance(file, dropbox.files.FileMetadata):
                metadata = {
                    'name': file.name,
                    'path_display': file.path_display,
                    'client_modified': file.client_modified,
                    'server_modified': file.server_modified
                }
                files_list.append(metadata)

        df = pd.DataFrame.from_records(files_list)
        return df.sort_values(by='server_modified', ascending=False)

    except Exception as e:
        print('Error getting list of files from Dropbox: ' + str(e))

dbx = dropbox.Dropbox(DROPBOX_ACCESS_TOKEN)
unscyned_shared_link = dbx.sharing_list_folders().entries[1].preview_url
dbx.files_list_folder('/SummitData/SummitContinuousBilateralStreaming/RCS07L',recursive=False, shared_link=dropbox.files.SharedLink(url=unscyned_shared_link)).entries[456]

# %%
dbx.sharing_get_shared_link_file_to_file('/Users/raphaelb/Documents/UW/Research/gridlab/optimal/data/rcs07/rcs/combined_original',unscyned_shared_link, path='/SummitData/SummitContinuousBilateralStreaming/RCS07L/Session1651792726456/.')
