# %%
import pandas as pd
from runeq import initialize
# Pull your rune authentication yaml from ~/.rune/config (C:\Users\<USERNAME>>\.rune\config on Windows)
initialize()

# %%
# To see information about your authenticated user
from runeq.resources.user import get_current_user 
my_user = get_current_user()
print(my_user) 
print('ActiveOrg:',my_user.active_org_name)
# Out:
# User(id="user-95316bb8df0035fb4794b9c40da74c2737a2661d,user", name="Thomas Kutcher")
# ActiveOrg: Baylor - TRD

# %%
# Get all the available patients and all the devices for each patient
from runeq.resources.patient import get_all_patients
patients = get_all_patients()
a_device = None
for patient in patients: 
    print(patient)
    for device in patient.devices: 
        a_device = device
        print(' ',device)
# Out:
# Patient(id="b79e9da25bd048008322a1d8d185fccd", name="Sai Test")
#   Device(id="fpO2V9Y2", name="Apple Watch", patient_id="b79e9da25bd048008322a1d8d185fccd")
#   Device(id="iU1bD*DQ", name="StrivePD", patient_id="b79e9da25bd048008322a1d8d185fccd")
#   Device(id="113Z*c4H", name="StrivePD", patient_id="b79e9da25bd048008322a1d8d185fccd")
#   Device(id="uH_IKv2X", name="Apple Watch", patient_id="b79e9da25bd048008322a1d8d185fccd")
# Patient(id="c2e72a4bc7004b19be199ab5c325bcfd", name="Thomas Test")
#   Device(id="qVQ245Mn", name="StrivePD", patient_id="c2e72a4bc7004b19be199ab5c325bcfd")
#   Device(id="5QKVqRiL", name="Apple Watch", patient_id="c2e72a4bc7004b19be199ab5c325bcfd")

# %%
a_device.patient_id
# Out:
# 'rcs07'

# %%
# Get the streams available for a particular patient
from runeq.resources.stream_metadata import get_patient_stream_metadata
patient_id = 'c2e72a4bc7004b19be199ab5c325bcfd'
patient_streams = get_patient_stream_metadata(patient_id)
print(f'Found {len(patient_streams)} total streams')
stream_df = patient_streams.to_dataframe()
display(stream_df)

categories = stream_df['category'].unique().tolist()
print(f'Found the following categories of streams: \n  {categories}')
# Out:
# Found 137 total streams
#        created_at                      algorithm device_id  \
# 0    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 1    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 2    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 3    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 4    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# ..            ...                            ...       ...
# 132  1.730669e+09      ingest-strive-healthkit.1  qVQ245Mn
# 133  1.729799e+09      ingest-strive-healthkit.1  qVQ245Mn
# 134  1.729795e+09      ingest-strive-healthkit.1  qVQ245Mn
# 135  1.734663e+09      ingest-strive-healthkit.1  qVQ245Mn
# 136  1.729799e+09      ingest-strive-healthkit.1  qVQ245Mn
#
#                            patient_id  \
# 0    c2e72a4bc7004b19be199ab5c325bcfd
# 1    c2e72a4bc7004b19be199ab5c325bcfd
# 2    c2e72a4bc7004b19be199ab5c325bcfd
# 3    c2e72a4bc7004b19be199ab5c325bcfd
# 4    c2e72a4bc7004b19be199ab5c325bcfd
# ..                                ...
# 132  c2e72a4bc7004b19be199ab5c325bcfd
# 133  c2e72a4bc7004b19be199ab5c325bcfd
# 134  c2e72a4bc7004b19be199ab5c325bcfd
# 135  c2e72a4bc7004b19be199ab5c325bcfd
# 136  c2e72a4bc7004b19be199ab5c325bcfd
#
#                                            stream_type      min_time  \
# 0    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 1    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 2    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 3    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 4    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# ..                                                 ...           ...
# 132  {'name': 'State', 'description': 'Current stat...  1.700889e+09
# 133  {'name': 'State', 'description': 'Current stat...  1.624286e+09
# 134  {'name': 'State', 'description': 'Current stat...  1.700876e+09
# 135  {'name': 'State', 'description': 'Current stat...  1.734413e+09
# 136  {'name': 'Timezone', 'description': 'Timezone,...  1.672979e+09
#
#          max_time                                         parameters  \
# 0    1.737653e+09  {'category': 'symptom', 'measurement': 'dyskin...
# 1    1.737653e+09  {'category': 'symptom', 'severity': 'none', 'm...
# 2    1.737653e+09  {'category': 'symptom', 'severity': 'strong', ...
# 3    1.737653e+09  {'category': 'symptom', 'severity': 'mild', 'm...
# 4    1.737653e+09  {'category': 'symptom', 'severity': 'unknown',...
# ..            ...                                                ...
# 132  1.702912e+09  {'category': 'sleep', 'measurement': 'sleep_st...
# 133  1.739203e+09  {'category': 'device_info', 'measurement': 'de...
# 134  1.739210e+09  {'category': 'vitals', 'measurement': 'heart_r...
# 135  1.739195e+09  {'category': 'sleep', 'measurement': 'sleep_st...
# 136  1.731380e+09  {'category': 'environment', 'measurement': 'ut...
#
#         category                measurement  \
# 0        symptom                 dyskinesia
# 1        symptom                     tremor
# 2        symptom                     tremor
# 3        symptom                     tremor
# 4        symptom                     tremor
# ..           ...                        ...
# 132        sleep                sleep_stage
# 133  device_info           device_placement
# 134       vitals  heart_rate_motion_context
# 135        sleep                sleep_stage
# 136  environment                 utc_offset
#
#                                                     id severity sleep_status  \
# 0    cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...      NaN          NaN
# 1    c3e4b2f20171302f02e06efcdfdbcbb3084a436f7ca2a8...     none          NaN
# 2    1960d0ebfef57daae44de462ddcf574700b26781bdaa17...   strong          NaN
# 3    b1e6100fb43e98f7f54800adc50557634fb2bee05f4985...     mild          NaN
# 4    c9f37ff1809d930e5ffa5e1d97ff40f70b9530cb1a0db1...  unknown          NaN
# ..                                                 ...      ...          ...
# 132  05a7a201133d87a5cc0b734add5273e277f66a2a47bad4...      NaN          NaN
# 133  fc719eb53d4cb61a628e00da088d847f3e9a26b70bc72e...      NaN          NaN
# 134  f8622539fad5f9d7a7c7a8701684e990f020ecf93e4af5...      NaN          NaN
# 135  9d09e432491350f23426474ecc5c2c1d4778d56d43f0cc...      NaN          NaN
# 136  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...      NaN          NaN
#
#     source_device user_entered function log_type
# 0             NaN          NaN      NaN      NaN
# 1             NaN          NaN      NaN      NaN
# 2             NaN          NaN      NaN      NaN
# 3             NaN          NaN      NaN      NaN
# 4             NaN          NaN      NaN      NaN
# ..            ...          ...      ...      ...
# 132  apple_health          NaN      NaN      NaN
# 133        iphone          NaN      NaN      NaN
# 134   apple_watch          NaN      NaN      NaN
# 135          oura          NaN      NaN      NaN
# 136  apple_health          NaN      NaN      NaN
#
# [137 rows x 17 columns]
# Found the following categories of streams:
#   ['symptom', 'sleep', 'motion', 'vitals', 'device_info', 'environment']

# %%
stream_df['date_end'] = pd.to_datetime(stream_df['max_time'], unit='s').dt.strftime('%Y-%m-%d')
date_end = stream_df['date_end'].unique().tolist()
print(f'Found the following categories of streams (end): \n  {date_end}')

stream_df['date_start'] = pd.to_datetime(stream_df['min_time'], unit='s').dt.strftime('%Y-%m-%d')
date_start = stream_df['date_start'].unique().tolist()
print(f'Found the following categories of streams (start): \n  {date_start}')

stream_df['date_create'] = pd.to_datetime(stream_df['created_at'], unit='s').dt.strftime('%Y-%m-%d')
date_create = stream_df['date_create'].unique().tolist()
print(f'Found the following categories of streams (create): \n  {date_create}')

print(stream_df['source_device'].unique().tolist())

display(stream_df)
# Out:
# Found the following categories of streams (end):
#   ['2025-01-23', '2025-02-10', '2024-11-12', '2023-12-18', '2023-11-25', '2025-01-14', '2025-01-30', '2025-02-11']
# Found the following categories of streams (start):
#   ['2024-10-23', '2024-12-17', '2023-01-06', '2023-11-25', '2021-06-19', '2024-12-16', '2021-06-21', '2021-06-20', '2021-11-11']
# Found the following categories of streams (create):
#   ['2024-10-23', '2024-12-20', '2024-10-24', '2024-11-03', '2024-11-04']
# [nan, 'oura', 'apple_health', 'iphone', 'apple_watch', 'unspecified']
#        created_at                      algorithm device_id  \
# 0    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 1    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 2    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 3    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# 4    1.729706e+09  ingest-strive-applewatch-md.0  5QKVqRiL
# ..            ...                            ...       ...
# 132  1.730669e+09      ingest-strive-healthkit.1  qVQ245Mn
# 133  1.729799e+09      ingest-strive-healthkit.1  qVQ245Mn
# 134  1.729795e+09      ingest-strive-healthkit.1  qVQ245Mn
# 135  1.734663e+09      ingest-strive-healthkit.1  qVQ245Mn
# 136  1.729799e+09      ingest-strive-healthkit.1  qVQ245Mn
#
#                            patient_id  \
# 0    c2e72a4bc7004b19be199ab5c325bcfd
# 1    c2e72a4bc7004b19be199ab5c325bcfd
# 2    c2e72a4bc7004b19be199ab5c325bcfd
# 3    c2e72a4bc7004b19be199ab5c325bcfd
# 4    c2e72a4bc7004b19be199ab5c325bcfd
# ..                                ...
# 132  c2e72a4bc7004b19be199ab5c325bcfd
# 133  c2e72a4bc7004b19be199ab5c325bcfd
# 134  c2e72a4bc7004b19be199ab5c325bcfd
# 135  c2e72a4bc7004b19be199ab5c325bcfd
# 136  c2e72a4bc7004b19be199ab5c325bcfd
#
#                                            stream_type      min_time  \
# 0    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 1    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 2    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 3    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# 4    {'name': 'Duration', 'description': 'Durations...  1.729705e+09
# ..                                                 ...           ...
# 132  {'name': 'State', 'description': 'Current stat...  1.700889e+09
# 133  {'name': 'State', 'description': 'Current stat...  1.624286e+09
# 134  {'name': 'State', 'description': 'Current stat...  1.700876e+09
# 135  {'name': 'State', 'description': 'Current stat...  1.734413e+09
# 136  {'name': 'Timezone', 'description': 'Timezone,...  1.672979e+09
#
#          max_time                                         parameters  \
# 0    1.737653e+09  {'category': 'symptom', 'measurement': 'dyskin...
# 1    1.737653e+09  {'category': 'symptom', 'severity': 'none', 'm...
# 2    1.737653e+09  {'category': 'symptom', 'severity': 'strong', ...
# 3    1.737653e+09  {'category': 'symptom', 'severity': 'mild', 'm...
# 4    1.737653e+09  {'category': 'symptom', 'severity': 'unknown',...
# ..            ...                                                ...
# 132  1.702912e+09  {'category': 'sleep', 'measurement': 'sleep_st...
# 133  1.739203e+09  {'category': 'device_info', 'measurement': 'de...
# 134  1.739210e+09  {'category': 'vitals', 'measurement': 'heart_r...
# 135  1.739195e+09  {'category': 'sleep', 'measurement': 'sleep_st...
# 136  1.731380e+09  {'category': 'environment', 'measurement': 'ut...
#
#         category                measurement  ... severity sleep_status  \
# 0        symptom                 dyskinesia  ...      NaN          NaN
# 1        symptom                     tremor  ...     none          NaN
# 2        symptom                     tremor  ...   strong          NaN
# 3        symptom                     tremor  ...     mild          NaN
# 4        symptom                     tremor  ...  unknown          NaN
# ..           ...                        ...  ...      ...          ...
# 132        sleep                sleep_stage  ...      NaN          NaN
# 133  device_info           device_placement  ...      NaN          NaN
# 134       vitals  heart_rate_motion_context  ...      NaN          NaN
# 135        sleep                sleep_stage  ...      NaN          NaN
# 136  environment                 utc_offset  ...      NaN          NaN
#
#     source_device user_entered function log_type        date    date_end  \
# 0             NaN          NaN      NaN      NaN  2025-01-23  2025-01-23
# 1             NaN          NaN      NaN      NaN  2025-01-23  2025-01-23
# 2             NaN          NaN      NaN      NaN  2025-01-23  2025-01-23
# 3             NaN          NaN      NaN      NaN  2025-01-23  2025-01-23
# 4             NaN          NaN      NaN      NaN  2025-01-23  2025-01-23
# ..            ...          ...      ...      ...         ...         ...
# 132  apple_health          NaN      NaN      NaN  2023-12-18  2023-12-18
# 133        iphone          NaN      NaN      NaN  2025-02-10  2025-02-10
# 134   apple_watch          NaN      NaN      NaN  2025-02-10  2025-02-10
# 135          oura          NaN      NaN      NaN  2025-02-10  2025-02-10
# 136  apple_health          NaN      NaN      NaN  2024-11-12  2024-11-12
#
#      date_start date_create
# 0    2024-10-23  2024-10-23
# 1    2024-10-23  2024-10-23
# 2    2024-10-23  2024-10-23
# 3    2024-10-23  2024-10-23
# 4    2024-10-23  2024-10-23
# ..          ...         ...
# 132  2023-11-25  2024-11-03
# 133  2021-06-21  2024-10-24
# 134  2023-11-25  2024-10-24
# 135  2024-12-17  2024-12-20
# 136  2023-01-06  2024-10-24
#
# [137 rows x 21 columns]

# %%
df = patient_streams.get_stream_dataframe()
display(df)
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
# /opt/miniconda3/lib/python3.12/site-packages/runeq/resources/stream_metadata.py:408: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   stream_df = pd.concat(all_stream_dfs, axis=0, ignore_index=True)
#                          time duration measurement_duration_ns  \
# 0        2024-10-23T17:30:00Z      0.0             60000000000
# 1        2024-10-23T17:31:00Z      0.0             60000000000
# 2        2024-10-23T17:32:00Z      0.0             60000000000
# 3        2024-10-23T17:33:00Z      0.0             60000000000
# 4        2024-10-23T17:34:00Z      0.0             60000000000
# ...                       ...      ...                     ...
# 2762896  2024-11-08T03:28:02Z      NaN          34320986892000
# 2762897  2024-11-09T04:21:45Z      NaN          31095927454000
# 2762898  2024-11-10T03:09:48Z      NaN          35414755755000
# 2762899  2024-11-11T03:33:04Z      NaN          34018644744900
# 2762900  2024-11-12T03:00:00Z      NaN          36000072187000
#
#                                                  stream_id stream_type_id  \
# 0        cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...       duration
# 1        cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...       duration
# 2        cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...       duration
# 3        cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...       duration
# 4        cd9527c2ab276f7b60be8d9090c79efac48c2acdda26cf...       duration
# ...                                                    ...            ...
# 2762896  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...       timezone
# 2762897  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...       timezone
# 2762898  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...       timezone
# 2762899  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...       timezone
# 2762900  26e5dc8df5803bfa0e2928926de3bd4771b54c378a0630...       timezone
#
#                                patient_id device_id  \
# 0        c2e72a4bc7004b19be199ab5c325bcfd  5QKVqRiL
# 1        c2e72a4bc7004b19be199ab5c325bcfd  5QKVqRiL
# 2        c2e72a4bc7004b19be199ab5c325bcfd  5QKVqRiL
# 3        c2e72a4bc7004b19be199ab5c325bcfd  5QKVqRiL
# 4        c2e72a4bc7004b19be199ab5c325bcfd  5QKVqRiL
# ...                                   ...       ...
# 2762896  c2e72a4bc7004b19be199ab5c325bcfd  qVQ245Mn
# 2762897  c2e72a4bc7004b19be199ab5c325bcfd  qVQ245Mn
# 2762898  c2e72a4bc7004b19be199ab5c325bcfd  qVQ245Mn
# 2762899  c2e72a4bc7004b19be199ab5c325bcfd  qVQ245Mn
# 2762900  c2e72a4bc7004b19be199ab5c325bcfd  qVQ245Mn
#
#                              algorithm     category measurement  ... rpm  \
# 0        ingest-strive-applewatch-md.0      symptom  dyskinesia  ... NaN
# 1        ingest-strive-applewatch-md.0      symptom  dyskinesia  ... NaN
# 2        ingest-strive-applewatch-md.0      symptom  dyskinesia  ... NaN
# 3        ingest-strive-applewatch-md.0      symptom  dyskinesia  ... NaN
# 4        ingest-strive-applewatch-md.0      symptom  dyskinesia  ... NaN
# ...                                ...          ...         ...  ...  ..
# 2762896      ingest-strive-healthkit.1  environment  utc_offset  ... NaN
# 2762897      ingest-strive-healthkit.1  environment  utc_offset  ... NaN
# 2762898      ingest-strive-healthkit.1  environment  utc_offset  ... NaN
# 2762899      ingest-strive-healthkit.1  environment  utc_offset  ... NaN
# 2762900      ingest-strive-healthkit.1  environment  utc_offset  ... NaN
#
#          start_time_min start_time end_time end_time_max event  speed state  \
# 0                   NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 1                   NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 2                   NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 3                   NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 4                   NaN        NaN      NaN          NaN   NaN    NaN   NaN
# ...                 ...        ...      ...          ...   ...    ...   ...
# 2762896             NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 2762897             NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 2762898             NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 2762899             NaN        NaN      NaN          NaN   NaN    NaN   NaN
# 2762900             NaN        NaN      NaN          NaN   NaN    NaN   NaN
#
#         timezone_offset  log_type
# 0                   NaN       NaN
# 1                   NaN       NaN
# 2                   NaN       NaN
# 3                   NaN       NaN
# 4                   NaN       NaN
# ...                 ...       ...
# 2762896           64800       NaN
# 2762897           64800       NaN
# 2762898           64800       NaN
# 2762899           64800       NaN
# 2762900           64800       NaN
#
# [2762901 rows x 29 columns]

# %%
# Look at the more specific attributes of the motion-related streams
grav_streams = patient_streams.filter(category='motion', measurement='gravity')
display(grav_streams.to_dataframe())

# %%
# Make a function for more customizable filtering of the available streams
from runeq.resources.stream_metadata import get_stream_metadata, get_stream_availability_dataframe
stream_meta = get_stream_metadata(list(grav_streams.ids())[0])

def is_x_stream(stream):
    return 'axis' in stream.parameters.keys() and stream.parameters['axis'] in ['x'] # , 'y', 'z']


x_streams = patient_streams.filter(filter_function=is_x_stream, measurement='user')
display(x_streams.to_dataframe())

# Get available times for May 4, 2023
try:
    available = x_streams.get_batch_availability_dataframe(
        start_time=1681408661, end_time=1681427545, timezone=-28800,
        batch_operation='any', resolution=60*15)
except Exception as e:
    print(e)
else:
    display(available)

# %%
import numpy as np
from runeq.resources.patient import get_device
# Get a list of devices with data available on a given day:
date = pd.Timestamp(1681427545, unit='s', tz='US/Pacific')
end_of_day = date + pd.Timedelta(hours=4)
resolution = 300

cumulative_avail = {}
for device in patient_streams.to_dataframe()['device_id'].unique():
    device_streams = x_streams.filter(device_id=device)
    try:
        device_avail = device_streams.get_batch_availability_dataframe(
            start_time=int(date.timestamp()), end_time=int(end_of_day.timestamp()), timezone=-28800,
            resolution=resolution, batch_operation='any'
        )
    except Exception as e:
        print(f'Device {device}')
        print(f'    {e}')
    else:
        # There is some data available for this device
        if sum(device_avail['availability']) > 0:
            print(f'Found data for {device}: {get_device(patient, device).name}')
            cumulative_avail[device] = device_avail
        else:
            print(f'No data for {device}')

# %%
# Given the devices from above, find the range of times with available data
if len(cumulative_avail):
    devices = list(cumulative_avail.keys())
    raw_avail = [df['availability'].to_numpy() for df in cumulative_avail.values()]
    cumulative = [np.sum(raw_avail, axis=0) >= 1][0]
    avail_times = (cumulative_avail[devices[0]]['time'][cumulative]).to_numpy()
    start, end = int(pd.Timestamp(avail_times[0]).timestamp()), int(pd.Timestamp(avail_times[-1]).timestamp()) + resolution
    print(f'Data for {devices} available between {start} and {end}')
else:
    print('NO DATA FOUND IN THE GIVEN TIME RANGE!')

# %%
# Get the data for the available time range
desired_ids = devices

all_data = []
for device in desired_ids:
    desired_streams = get_patient_stream_metadata('rcs07', device) # .filter(category='motion')
    print(f'Data for {device}: {get_device(patient, device).name}')
    print(f'Found {len(list(desired_streams.ids()))} streams over {(end - start) / 60} minutes.')
    # for stream_id in desired_streams.ids():
    #     stream = get_stream_metadata(stream_id,)
    #     print(f'Fetching: {stream.parameters}')
    #     stream_data = stream.get_stream_dataframe(
    #         start_time=start, end_time=end
    #     )
    #     all_data.append(stream_data)
# Out:
# Data for GNmN5Ps_: Apple Watch Left 011823
# Found 26 streams over 5.0 minutes.
# Data for mn69eHPB: Apple Watch Right 011823
# Found 27 streams over 5.0 minutes.

# %%
desired_streams.to_dataframe()
# Out:
#       created_at                          algorithm device_id patient_id  \
# 0   1.682662e+09               ingest-rune-events.0  mn69eHPB      rcs07
# 1   1.676579e+09               ingest-rune-events.0  mn69eHPB      rcs07
# 2   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 3   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 4   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 5   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 6   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 7   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 8   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 9   1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 10  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 11  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 12  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 13  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 14  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 15  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 16  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 17  1.674083e+09      ingest-strive-applewatch-md.0  mn69eHPB      rcs07
# 18  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 19  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 20  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 21  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 22  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 23  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 24  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 25  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
# 26  1.674084e+09  ingest-strive-applewatch-motion.0  mn69eHPB      rcs07
#
#                                           stream_type      min_time  \
# 0   {'name': 'Event', 'description': 'Occurrences ...  1.682661e+09
# 1   {'name': 'Event', 'description': 'Occurrences ...  1.674082e+09
# 2   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 3   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 4   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 5   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 6   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 7   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 8   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 9   {'name': 'Duration', 'description': 'Durations...  1.674082e+09
# 10  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 11  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 12  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 13  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 14  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 15  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 16  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 17  {'name': 'Percentage', 'description': 'Percent...  1.674082e+09
# 18  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 19  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 20  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 21  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 22  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 23  {'name': 'Acceleration', 'description': 'Accel...  1.674083e+09
# 24  {'name': 'Rotation', 'description': 'Rotation ...  1.674083e+09
# 25  {'name': 'Rotation', 'description': 'Rotation ...  1.674083e+09
# 26  {'name': 'Rotation', 'description': 'Rotation ...  1.674083e+09
#
#         max_time                                         parameters  \
# 0   1.682661e+09  {'category': 'patient_report', 'measurement': ...
# 1   1.677781e+09  {'category': 'patient_report', 'log_type': 'st...
# 2   1.685057e+09  {'category': 'symptom', 'severity': 'moderate'...
# 3   1.685057e+09  {'category': 'symptom', 'severity': 'all', 'me...
# 4   1.685057e+09  {'category': 'symptom', 'severity': 'unknown',...
# 5   1.685057e+09  {'category': 'symptom', 'measurement': 'dyskin...
# 6   1.685057e+09  {'category': 'symptom', 'severity': 'mild', 'm...
# 7   1.685057e+09  {'category': 'symptom', 'severity': 'strong', ...
# 8   1.685057e+09  {'category': 'symptom', 'severity': 'slight', ...
# 9   1.685057e+09  {'category': 'symptom', 'severity': 'none', 'm...
# 10  1.685057e+09  {'category': 'symptom', 'severity': 'moderate'...
# 11  1.685057e+09  {'category': 'symptom', 'severity': 'all', 'me...
# 12  1.685057e+09  {'category': 'symptom', 'severity': 'unknown',...
# 13  1.685057e+09  {'category': 'symptom', 'measurement': 'dyskin...
# 14  1.685057e+09  {'category': 'symptom', 'severity': 'none', 'm...
# 15  1.685057e+09  {'category': 'symptom', 'severity': 'strong', ...
# 16  1.685057e+09  {'category': 'symptom', 'severity': 'mild', 'm...
# 17  1.685057e+09  {'category': 'symptom', 'severity': 'slight', ...
# 18  1.686704e+09  {'axis': 'y', 'category': 'motion', 'measureme...
# 19  1.686704e+09  {'axis': 'y', 'category': 'motion', 'measureme...
# 20  1.686704e+09  {'axis': 'x', 'category': 'motion', 'measureme...
# 21  1.686704e+09  {'axis': 'x', 'category': 'motion', 'measureme...
# 22  1.686704e+09  {'axis': 'z', 'category': 'motion', 'measureme...
# 23  1.686704e+09  {'axis': 'z', 'category': 'motion', 'measureme...
# 24  1.686704e+09                {'axis': 'x', 'category': 'motion'}
# 25  1.686704e+09                {'axis': 'y', 'category': 'motion'}
# 26  1.686704e+09                {'axis': 'z', 'category': 'motion'}
#
#           category                       measurement  \
# 0   patient_report  watch_recording_stop_low_battery
# 1   patient_report            watch_recording_manual
# 2          symptom                            tremor
# 3          symptom                            tremor
# 4          symptom                            tremor
# 5          symptom                        dyskinesia
# 6          symptom                            tremor
# 7          symptom                            tremor
# 8          symptom                            tremor
# 9          symptom                            tremor
# 10         symptom                            tremor
# 11         symptom                            tremor
# 12         symptom                            tremor
# 13         symptom                        dyskinesia
# 14         symptom                            tremor
# 15         symptom                            tremor
# 16         symptom                            tremor
# 17         symptom                            tremor
# 18          motion                              user
# 19          motion                           gravity
# 20          motion                           gravity
# 21          motion                              user
# 22          motion                           gravity
# 23          motion                              user
# 24          motion                               NaN
# 25          motion                               NaN
# 26          motion                               NaN
#
#                                                    id log_type  severity axis
# 0   a357d0cc64293975d2a4b93f03482a9878dbfcdff5647d...      NaN       NaN  NaN
# 1   32ae6f2f037e96f31df66d68d2e759b753f823565e944d...    start       NaN  NaN
# 2   ecd8f5ea4a9ca1f6650879ca18bb3d9905b5e31139811d...      NaN  moderate  NaN
# 3   f6e1b9abc9c83c553b53220ef4b490b80a239e437ed55d...      NaN       all  NaN
# 4   bdfbe75dde014c71d1749713c05653315b3bf2872771b0...      NaN   unknown  NaN
# 5   e62e732570bfff24bcdf8a9f6779834f54de7a45ddc06d...      NaN       NaN  NaN
# 6   4cded6ba90577ec63cbcf09400ce53d94f00700f6a0b92...      NaN      mild  NaN
# 7   0b23cf09421e01b46a802f6521b4061a5e1674a6a1a31d...      NaN    strong  NaN
# 8   0cea5ee2938b233f4c44d38e13d3fd3647df3452f1cc56...      NaN    slight  NaN
# 9   0e6e5b1ad8946624af43cfb4e74424a036d4eac2e51832...      NaN      none  NaN
# 10  f530d041ce3c31cfab23ebe04b2d12f53694ca5ca24bd5...      NaN  moderate  NaN
# 11  8dfdc7abcf0cd6b56735cbdb709f22a5ed8a4c7540f2da...      NaN       all  NaN
# 12  c0978fac4f335f455db7ca85de80245791c60ea00ac4ec...      NaN   unknown  NaN
# 13  eae0a1d7c4b84a90bb42db7d1ed4f1b8111adf24563982...      NaN       NaN  NaN
# 14  cf8b6f2edec1732bf32caa8eab106db0faed632103a297...      NaN      none  NaN
# 15  7293805ba85e11d59399f6de14dfe62f6a794467660894...      NaN    strong  NaN
# 16  8bc50566661e4a7bb48fe2d3da659e62d925193dbb80a5...      NaN      mild  NaN
# 17  e32d8d47637ca64cd7723a2792769a3f988ed25920c0de...      NaN    slight  NaN
# 18  9f0e8149201e6eda540ae6d0d060e79dca2e8ecb149d56...      NaN       NaN    y
# 19  0dc5b6c50ea389a4d90c6ef88a284f674e37d4d5b6f158...      NaN       NaN    y
# 20  c6dd49ba9bb7c545067bdf55338c0f0694a5229c98330b...      NaN       NaN    x
# 21  adb411995e64ec3540e53eba88b566304fe94725296840...      NaN       NaN    x
# 22  3edf20fbc7ebd3c5db0fae47abc14e3eb00e9534958cf9...      NaN       NaN    z
# 23  7857f79ec09b690a2f2393091d251aa0b19d0b21af9443...      NaN       NaN    z
# 24  b53d28bb7af688135f21843f6ccd60c97a73a3693323c4...      NaN       NaN    x
# 25  0be95dfbf640adb9678a1f664bf60f4c64f8ac7536c2bf...      NaN       NaN    y
# 26  ff595d0057a87e6f9ef73769bb8b6a9a15e6e27ef408ed...      NaN       NaN    z

# %%
stream = get_stream_metadata(list(desired_streams.ids())[0])
